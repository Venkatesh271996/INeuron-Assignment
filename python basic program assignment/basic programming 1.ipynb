# %% [markdown]
# 1. Write a Python program to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# 2. Write a Python program to do arithmetical operations addition and division.?

# %%
try:
  first_number=int(input("Enrter a number: "))
  second_number=int(input("Enter a second number: "))
  addition=first_number+second_number
  print("The sum of two numbers is",addition )
  division=first_number/second_number
  print("The divison of the two numbers is",division)
except:
  print("Enter a valid number other than Zero")
# Out:
# Enrter a number: 25
# Enter a second number: 12
# The sum of two numbers is 37
# The divison of the two numbers is 2.0833333333333335

# %% [markdown]
# 3. Write a Python program to find the area of a triangle?

# %%
base=int(input("Enter the base of the triangle: "))
height=int(input("Enter the height of the triangle: "))
area=base*height/2
print("The area of the triangle is",area)
# Out:
# Enter the base of the triangle: 125
# Enter the height of the triangle: 1456
# The area of the triangle is 91000.0

# %% [markdown]
# 4. Write a Python program to swap two variables?

# %%
first_number=int(input("Enrter the first number: "))
second_number=int(input("Enter the second number: "))
print("The first and second number before swapping are",first_number,"and",second_number)
temp = first_number
first_number = second_number
second_number = temp
print("The first and second number after swapping are",first_number,"and",second_number)
# Out:
# Enrter the first number: 12
# Enter the second number: 2
# The first and second number before swapping are 12 and 2
# The first and second number after swapping are 2 and 12

# %% [markdown]
# 5. Write a Python program to generate a random number?

# %%
from random import randint
def RandomNumber(start=0,end=100000):
    print('The generated random number is',randint(start,end))
RandomNumber(10,100)
# Out:
# The generated random number is 39

# %% [markdown]
# Question 1: Define a class with a generator which can iterate the numbers, which are divisible by 7, between a given range 0 and n.

# %%
class div_generator:
    def __init__(self,in_num):
        self.in_num = in_num
    def get_numbers(self):
        for ele in range(0,self.in_num+1):
            if ele%7 == 0:
                yield ele
n=int(input("enter the n: "))
output = div_generator(n)
for ele in output.get_numbers():
    print(ele,end=' ')
# Out:
# enter the n: 1000
# 0 7 14 21 28 35 42 49 56 63 70 77 84 91 98 105 112 119 126 133 140 147 154 161 168 175 182 189 196 203 210 217 224 231 238 245 252 259 266 273 280 287 294 301 308 315 322 329 336 343 350 357 364 371 378 385 392 399 406 413 420 427 434 441 448 455 462 469 476 483 490 497 504 511 518 525 532 539 546 553 560 567 574 581 588 595 602 609 616 623 630 637 644 651 658 665 672 679 686 693 700 707 714 721 728 735 742 749 756 763 770 777 784 791 798 805 812 819 826 833 840 847 854 861 868 875 882 889 896 903 910 917 924 931 938 945 952 959 966 973 980 987 994

# %% [markdown]
# Question 2:
# Write a program to compute the frequency of the words from the input. The output should output after sorting the key alphanumerically.
#
# Suppose the following input is supplied to the program:
#
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or
# Python 3.
#
# Then, the output should be:
# 2:2
#
# 3.:1
#
# 3?:1
#
# New:1
#
# Python:5
#
# Read:1
#
# and:1
#
# between:1
#
# choosing:1
#
# or:2
#
# to:1

# %%
from collections import OrderedDict
input_value=input("enter the input string: ")
def checking_frequency(input_val):
  input_list=input_val.split(" ")
  frequency_dict={}
  for element in input_list:
    if element not in frequency_dict.keys():
      frequency_dict[element]=1
    else:
      frequency_dict[element]+=1
  return OrderedDict(sorted(frequency_dict.items()))
print("The output of the given string is")
output=checking_frequency(input_value)
for ele in output:
  print(f'{ele}:{output[ele]}')
# Out:
# enter the input string: hello world welcome to the my new page
# The output of the given program is
# hello:1
# my:1
# new:1
# page:1
# the:1
# to:1
# welcome:1
# world:1

# %% [markdown]
# Question 3:
#
# Define a class Person and its two child classes: Male and Female. All classes have a method "getGender" which can print "Male" for Male class and "Female" for Female class.

# %%
class Person():
    def getGender():
        pass
    
class Male(Person):
    def getGender():
        print("Male")
        
class Female(Person):
    def getGender():
        print("Female")

Male.getGender()
Female.getGender()
# Out:
# Male
# Female

# %% [markdown]
# Question 4:
#
# Please write a program to generate all sentences where subject is in ["I", "You"] and verb is in ["Play", "Love"] and the object is in ["Hockey","Football"].

# %%
def sentence(sub,ver,obj):
  for i in sub:
    for j in ver:
      for k in obj:
        print(f"{i} {j} {k}")
subject=["I", "You"]
verb= ["Play", "Love"]
obje=["Hockey","Football"]
sentence(subject,verb,obje)
# Out:
# I Play Hockey
# I Play Football
# I Love Hockey
# I Love Football
# You Play Hockey
# You Play Football
# You Love Hockey
# You Love Football

# %% [markdown]
# Question 5: Please write a program to compress and decompress the string "hello world!hello world!hello world!hello world!".

# %%
import zlib

def comp_and_decomp(string):

  string=bytes(string,'utf-8')
  compressed_string=zlib.compress(string)
  print("The compressed string is")
  print(compressed_string)
  decomposed_string=zlib.decompress(compressed_string)
  print("The decompressed string is")
  print(decomposed_string)

input_string=input("Enter the string:")
comp_and_decomp(input_string)
# Out:
# Enter the string:Hello world
# The compressed string is
# b'x\x9c\xf3H\xcd\xc9\xc9W(\xcf/\xcaI\x01\x00\x18\xab\x04='
# The decompressed string is
# b'Hello world'

# %% [markdown]
# Question 6: Please write a binary search function which searches an item in a sorted list. The function should return the index of element to be searched in the list.

# %%
def binary_search(list1, n):  
    low = 0  
    high = len(list1) - 1  
    mid = 0  
  
    while low <= high:  
        mid = (high + low) // 2  
        if list1[mid] < n:  
            low = mid + 1  
        elif list1[mid] > n:  
            high = mid - 1  
        else:  
            return mid  
    return -1  
   
list1 = [12, 24, 32, 39, 45, 50, 54]  
n = 45   
result = binary_search(list1, n)  
  
if result != -1:  
    print("Element is present at index", str(result))  
else:  
    print("Element is not present in list1")
# Out:
# Element is present at index 4

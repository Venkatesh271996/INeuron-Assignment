# %% [markdown]
# 1. Write a Python Program to Display Fibonacci Sequence Using Recursion?

# %%
def recur_fibo(n):  
   if n <= 1:  
       return n  
   else:  
       return(recur_fibo(n-1) + recur_fibo(n-2))  
number_of_terms = int(input("How many terms? "))  
if number_of_terms <= 0:  
   print("Plese enter a positive integer")  
else:  
   print("Fibonacci sequence:")  
   for i in range(number_of_terms):  
       print(recur_fibo(i))
# Out:
# How many terms? 5
# Fibonacci sequence:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# 2. Write a Python Program to Find Factorial of Number Using Recursion?

# %%
def factorial(x):
  if x==1:
    return 1
  else:
    return x*factorial(x-1)
number=int(input("Enter the number: "))
print(f"The factorial of the {number} is",factorial(number))
# Out:
# Enter the number7
# The factorial of the 7 is 5040

# %% [markdown]
# 3. Write a Python Program to calculate your Body Mass Index?

# %%
weight=float(input("Enter the weight in kgs: "))
height=float(input("Enter the height in cms: "))

bmi= weight/(height/100)**2

if bmi<=18.5:
  print("You are underweight")
elif bmi<=24.9:
  print("You are healthy")
elif bmi<=29.9:
  print("You are overweight")
else:
  print("You are obese")
# Out:
# Enter the weight: 83
# Enter the height: 172
# You are overweight

# %% [markdown]
# 4. Write a Python Program to calculate the natural logarithm of any number?

# %%
import math
number=int(input("Enter the number: "))
print(f"The natural log of {number} is",math.log(number))
# Out:
# Enter the number: 6
# The natural log of 6 is 1.791759469228055

# %% [markdown]
# 5. Write a Python Program for cube sum of first n natural numbers?

# %%
number=int(input("Enter the number: "))
answer=(number*(number+1)/2)**2
print(f"The cube sum of first {number} natural number is",answer)
# Out:
# Enter the number: 10
# The cube sum of first 10 natural number is 3025.0
